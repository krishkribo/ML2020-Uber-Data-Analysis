# %% [markdown]
# ### LSTM - Feature columns: All Features || Prediction: Pickup count by Borough

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# FIX ME: Root dir as argument
root_dir = "../../data/picklerCheckpoints/"
is_compressed = True;
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import numpy as np
import pandas as pd
import nbimporter
import geopandas as gpd
import commons.utility.pickle_util as pickle
import Preprocessing.SpatialMapping as sm
import Preprocessing.Discretization as dis
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import time
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import tensorflow as tf

coord_system = {'init': 'epsg:4326'}
# Out:
# Importing Jupyter notebook from D:\Academics\MLRepoFeb\ML2020-Uber-Data-Analysis\commons\utility\pickle_util.ipynb
# Importing Jupyter notebook from D:\Academics\MLRepoFeb\ML2020-Uber-Data-Analysis\Preprocessing\SpatialMapping.ipynb
# Importing Jupyter notebook from D:\Academics\MLRepoFeb\ML2020-Uber-Data-Analysis\Preprocessing\DataEnrichment.ipynb
# Importing Jupyter notebook from D:\Academics\MLRepoFeb\ML2020-Uber-Data-Analysis\Preprocessing\Discretization.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
from pandas import concat
from matplotlib import pyplot

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.preprocessing.sequence import TimeseriesGenerator
import keras
from keras import layers

# %%
data = sm.run(['apr', 'may', 'jun', 'jul', 'aug'])
# Out:
# Data for the month :apr Found.....
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-apr14.p
# Decompressing ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-apr14.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Data for the month :may Found.....
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-may14.p
# Decompressing ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-may14.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Data for the month :jun Found.....
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-jun14.p
# Decompressing ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-jun14.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Data for the month :jul Found.....
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-jul14.p
# Decompressing ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-jul14.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Data for the month :aug Found.....
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-aug14.p
# Decompressing ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-aug14.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def ljust(lst, n, fillvalue=0):
    return lst + [fillvalue] * (n - len(lst))

# %%
def transposeZones(df2, column):
    dftest = df2[['datetime', column, 'pickups']]
    dftest = dftest.sort_values(['datetime', column], ascending=[True, True]).set_index('datetime')
    #dftest.head(len(dftest.zone.unique())-1)
    zone_order = dftest[column].unique()
#     print(zone_order)
    dftest = dftest.groupby('datetime').agg({lambda x: x.tolist()})
    a = dftest.loc[:, ['pickups']].T
    b = dftest.loc[:, [column]].T
    N = len(zone_order)
    M = np.shape(a)[1]
    acc = []
    idx = 0
    for date in a.columns:
        sub_list_start = 0
        sub_list_end = len(a[date])
        row = a[date].values[0]
        acc.append(ljust(row, N))
       # zeros[idx][sub_list_start : sub_list_end+1] = a[date]
        idx = idx + 1
#     print(acc[0])
    zoneDf = pd.DataFrame(acc, columns=zone_order)
    df3 = df2[['datetime', 'dayOfWeek', 'hourOfDay', 'humidity', 'pressure', 'temperature', 'windDirection', 'holiday', 'windSpeed']].drop_duplicates().reset_index()
    return pd.merge(df3, zoneDf, left_index=True, right_index=True).drop(['index', 'datetime'], 1)

# %%
df = data.copy()

# %%
df2 = df[['datetime', 'borough', 'weatherCondition', 'humidity', 'pressure', 'temperature', 'windDirection', 'windSpeed', 'holiday']]

# %%
df2 = dis.encode(df2, ['holiday', 'weatherCondition', 'borough'])
# Out:
# D:\Academics\MLRepoFeb\ML2020-Uber-Data-Analysis\Preprocessing\Discretization.ipynb:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# Result Saved in ../data/encodedMappings/holiday.p
# Result Saved in ../data/encodedMappings/weatherCondition.p
# Result Saved in ../data/encodedMappings/borough.p

# %%
df2['dayOfWeek'] = pd.to_datetime(df2['datetime'], format='%m-%d-%Y:%H')
df2['hourOfDay'] =  pd.to_datetime(df2['datetime'], format='%m-%d-%Y:%H')
df2['dayOfWeek'] = df2['dayOfWeek'].dt.day_name()
df2['hourOfDay'] = df2['hourOfDay'].dt.hour
# Out:
# <ipython-input-14-9ac9e5788ff7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['dayOfWeek'] = pd.to_datetime(df2['datetime'], format='%m-%d-%Y:%H')
# <ipython-input-14-9ac9e5788ff7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['hourOfDay'] =  pd.to_datetime(df2['datetime'], format='%m-%d-%Y:%H')
# <ipython-input-14-9ac9e5788ff7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['dayOfWeek'] = df2['dayOfWeek'].dt.day_name()
# <ipython-input-14-9ac9e5788ff7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['hourOfDay'] = df2['hourOfDay'].dt.hour

# %%
week_dict = {
    "Sunday": 1,
    "Monday": 2,
    "Tuesday": 3,
    "Wednesday":4,
    "Thursday":5,
    "Friday": 6,
    "Saturday": 7
}

# %%
df2['dayOfWeek'] = df2.dayOfWeek.apply(lambda x: week_dict[x])
# Out:
# <ipython-input-16-35d0f5211b87>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['dayOfWeek'] = df2.dayOfWeek.apply(lambda x: week_dict[x])

# %%
# data

# %%
# cols_to_norm = ['humidity','pressure', 'temperature', 'windDirection', 'windSpeed']
# df2[cols_to_norm] = df2[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
feature_cols = ['datetime', 'borough', 'dayOfWeek', 'hourOfDay', 'humidity','pressure', 'temperature', 'windDirection', 'holiday', 'windSpeed']
df2 = df2[feature_cols]
N = len(df2['borough'].unique())

# %%
df2 = df2.groupby(feature_cols).size().reset_index(name='pickups')

# %%
# pickups = df2['pickups']
# pickups.pop(0)
# pickups.reset_index(inplace=True, drop=True)
# df2.drop(df2.tail(1).index,inplace=True)

# %%
# df2['Pickups_t-1h'] = pickups 
# df2['zone'] = df2['borough']

# %%
df2 = transposeZones(df2, 'borough')

# %%
df2
# Out:
#       dayOfWeek  hourOfDay  humidity  pressure  temperature  windDirection  \
# 0             3          0      40.0    1016.0       282.96          330.0
# 1             3          3      60.0    1018.0       278.07           20.0
# 2             3          4      60.0    1019.0       277.19          360.0
# 3             3          5      60.0    1019.0       276.49          340.0
# 4             3          6      64.0    1020.0       275.99          290.0
# ...         ...        ...       ...       ...          ...            ...
# 3629          1         19      46.0    1016.0       303.45          230.0
# 3630          1         20      46.0    1015.0       302.18          220.0
# 3631          1         21      88.0    1016.0       299.70          240.0
# 3632          1         22      94.0    1015.0       298.71            0.0
# 3633          1         23      88.0    1015.0       298.53            0.0
#
#       holiday  windSpeed   1    3    4     2    0  5
# 0           1        5.0  26  239   16     0    0  0
# 1           1        6.0  33    2  133    12    0  0
# 2           1        4.0  62    4  212    23    0  0
# 3           1        4.0   2  125    4   447   44  0
# 4           1        3.0   9  192    3  1289   54  2
# ...       ...        ...  ..  ...  ...   ...  ... ..
# 3629        2        7.0  27  497   15  1775  256  0
# 3630        2        6.0  45  574   13  1458  267  2
# 3631        2        6.0  22  570   12  1726  317  4
# 3632        2        1.0  37  497   16  1702  274  2
# 3633        2        2.0  22  463    8  1179  193  0
#
# [3634 rows x 14 columns]

# %%
# feature_cols = ['datetime', 'zone', 'dayOfWeek', 'hourOfDay', 'humidity','pressure', 'temperature', 'windDirection', 'windSpeed', 'Pickups_t-1h', 'pickups']
# df2 = df2[feature_cols]

# %%
values = df2.values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(df2)

# %%
reframed = series_to_supervised(scaled, 7, N)

# %%
listOfDrops = []
for i in range(7*len(df2.columns),len(reframed.columns)):
    listOfDrops.append(i)

# print("list of drops ", listOfDrops)
reframed.drop(reframed.columns[listOfDrops], axis=1, inplace=True)

# %%
values = reframed.values

# %%
np.shape(df2)
# Out:
# (3634, 14)

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 3000 
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-N], train[:, -N:]
test_X, test_y = test[:, :-N], test[:, -N:]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (3000, 1, 92) (3000, 6) (622, 1, 92) (622, 6)

# %%
reframed
# Out:
#       var1(t-7)  var2(t-7)  var3(t-7)  var4(t-7)  var5(t-7)  var6(t-7)  \
# 7      0.333333   0.000000   0.333333   0.425532   0.309007   0.916667
# 8      0.333333   0.130435   0.555556   0.468085   0.167391   0.055556
# 9      0.333333   0.173913   0.555556   0.489362   0.141906   1.000000
# 10     0.333333   0.217391   0.555556   0.489362   0.121633   0.944444
# 11     0.333333   0.260870   0.600000   0.510638   0.107153   0.805556
# ...         ...        ...        ...        ...        ...        ...
# 3624   0.000000   0.304348   0.811111   0.531915   0.649290   0.527778
# 3625   0.000000   0.347826   0.811111   0.510638   0.648711   0.555556
# 3626   0.000000   0.391304   0.700000   0.510638   0.651318   0.527778
# 3627   0.000000   0.434783   0.755556   0.510638   0.650449   0.555556
# 3628   0.000000   0.478261   0.700000   0.510638   0.651318   0.638889
#
#       var7(t-7)  var8(t-7)  var9(t-7)  var10(t-7)  ...  var5(t-1)  var6(t-1)  \
# 7           0.5   0.416667   0.090253    0.254002  ...   0.076745   0.916667
# 8           0.5   0.500000   0.115523    0.001067  ...   0.066319   0.861111
# 9           0.5   0.333333   0.220217    0.003202  ...   0.066319   0.888889
# 10          0.5   0.333333   0.003610    0.132337  ...   0.072111   0.972222
# 11          0.5   0.250000   0.028881    0.203842  ...   0.120185   0.944444
# ...         ...        ...        ...         ...  ...        ...        ...
# 3624        1.0   0.250000   0.050542    0.169691  ...   0.676513   0.638889
# 3625        1.0   0.333333   0.043321    0.284952  ...   0.703446   0.555556
# 3626        1.0   0.250000   0.054152    0.381003  ...   0.752389   0.611111
# 3627        1.0   0.250000   0.064982    0.324440  ...   0.798726   0.638889
# 3628        1.0   0.083333   0.144404    0.402348  ...   0.847669   0.583333
#
#       var7(t-1)  var8(t-1)  var9(t-1)  var10(t-1)  var11(t-1)  var12(t-1)  \
# 7           0.5   0.250000   0.014440    0.186766    0.001378    0.217729
# 8           0.5   0.250000   0.003610    0.150480    0.000551    0.143038
# 9           0.5   0.250000   0.014440    0.088581    0.002205    0.129083
# 10          0.5   0.250000   0.014440    0.107791    0.258269    0.010942
# 11          0.5   0.333333   0.025271    0.100320    0.001654    0.124326
# ...         ...        ...        ...         ...         ...         ...
# 3624        1.0   0.333333   0.101083    0.485592    0.004410    0.244529
# 3625        1.0   0.250000   0.119134    0.588047    0.004686    0.270536
# 3626        1.0   0.416667   0.140794    0.553895    0.003032    0.384237
# 3627        1.0   0.500000   0.126354    0.560299    0.003032    0.408024
# 3628        1.0   0.500000   0.097473    0.551761    0.002481    0.358706
#
#       var13(t-1)  var14(t-1)
# 7       0.174334    0.000000
# 8       0.145278    0.111111
# 9       0.133172    0.333333
# 10      0.000000    0.000000
# 11      0.130751    0.000000
# ...          ...         ...
# 3624    0.578692    0.000000
# 3625    0.598063    0.000000
# 3626    0.646489    0.333333
# 3627    0.610169    0.000000
# 3628    0.726392    0.000000
#
# [3622 rows x 98 columns]

# %%
NumOfEpochs = 300
# design network
model = Sequential()
model.add(layers.LSTM(NumOfEpochs, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(layers.Dense(N))
model.compile(loss='mae', optimizer='adam', metrics=['accuracy'])
# fit network
start = time.time()
history = model.fit(train_X, train_y, epochs=NumOfEpochs, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
end = time.time()
# Out:
# Epoch 1/300
# 42/42 - 1s - loss: 0.0733 - accuracy: 0.4137 - val_loss: 0.0684 - val_accuracy: 0.6511
# Epoch 2/300
# 42/42 - 0s - loss: 0.0601 - accuracy: 0.5117 - val_loss: 0.0588 - val_accuracy: 0.6785
# Epoch 3/300
# 42/42 - 0s - loss: 0.0578 - accuracy: 0.4987 - val_loss: 0.0575 - val_accuracy: 0.6913
# Epoch 4/300
# 42/42 - 0s - loss: 0.0555 - accuracy: 0.5217 - val_loss: 0.0577 - val_accuracy: 0.6688
# Epoch 5/300
# 42/42 - 0s - loss: 0.0546 - accuracy: 0.4987 - val_loss: 0.0564 - val_accuracy: 0.6383
# Epoch 6/300
# 42/42 - 0s - loss: 0.0549 - accuracy: 0.4993 - val_loss: 0.0526 - val_accuracy: 0.7026
# Epoch 7/300
# 42/42 - 0s - loss: 0.0527 - accuracy: 0.5373 - val_loss: 0.0561 - val_accuracy: 0.7026
# Epoch 8/300
# 42/42 - 0s - loss: 0.0525 - accuracy: 0.5573 - val_loss: 0.0514 - val_accuracy: 0.7074
# Epoch 9/300
# 42/42 - 0s - loss: 0.0498 - accuracy: 0.5747 - val_loss: 0.0505 - val_accuracy: 0.6961
# Epoch 10/300
# 42/42 - 0s - loss: 0.0488 - accuracy: 0.5813 - val_loss: 0.0514 - val_accuracy: 0.6913
# Epoch 11/300
# 42/42 - 0s - loss: 0.0474 - accuracy: 0.5950 - val_loss: 0.0482 - val_accuracy: 0.6929
# Epoch 12/300
# 42/42 - 0s - loss: 0.0463 - accuracy: 0.5993 - val_loss: 0.0483 - val_accuracy: 0.6994
# Epoch 13/300
# 42/42 - 0s - loss: 0.0461 - accuracy: 0.5963 - val_loss: 0.0485 - val_accuracy: 0.6977
# Epoch 14/300
# 42/42 - 0s - loss: 0.0458 - accuracy: 0.6050 - val_loss: 0.0484 - val_accuracy: 0.7042
# Epoch 15/300
# 42/42 - 0s - loss: 0.0456 - accuracy: 0.6103 - val_loss: 0.0476 - val_accuracy: 0.7106
# Epoch 16/300
# 42/42 - 0s - loss: 0.0447 - accuracy: 0.6127 - val_loss: 0.0466 - val_accuracy: 0.7138
# Epoch 17/300
# 42/42 - 0s - loss: 0.0440 - accuracy: 0.6163 - val_loss: 0.0459 - val_accuracy: 0.7154
# Epoch 18/300
# 42/42 - 0s - loss: 0.0434 - accuracy: 0.6150 - val_loss: 0.0464 - val_accuracy: 0.7138
# Epoch 19/300
# 42/42 - 0s - loss: 0.0437 - accuracy: 0.6157 - val_loss: 0.0457 - val_accuracy: 0.7235
# Epoch 20/300
# 42/42 - 0s - loss: 0.0434 - accuracy: 0.6113 - val_loss: 0.0470 - val_accuracy: 0.7186
# Epoch 21/300
# 42/42 - 0s - loss: 0.0442 - accuracy: 0.6053 - val_loss: 0.0467 - val_accuracy: 0.7219
# Epoch 22/300
# 42/42 - 0s - loss: 0.0441 - accuracy: 0.6080 - val_loss: 0.0458 - val_accuracy: 0.7283
# Epoch 23/300
# 42/42 - 0s - loss: 0.0438 - accuracy: 0.6000 - val_loss: 0.0456 - val_accuracy: 0.7235
# Epoch 24/300
# 42/42 - 0s - loss: 0.0444 - accuracy: 0.6067 - val_loss: 0.0459 - val_accuracy: 0.7283
# Epoch 25/300
# 42/42 - 0s - loss: 0.0439 - accuracy: 0.6100 - val_loss: 0.0454 - val_accuracy: 0.7219
# Epoch 26/300
# 42/42 - 0s - loss: 0.0426 - accuracy: 0.6160 - val_loss: 0.0449 - val_accuracy: 0.7170
# Epoch 27/300
# 42/42 - 0s - loss: 0.0424 - accuracy: 0.6153 - val_loss: 0.0445 - val_accuracy: 0.7315
# Epoch 28/300
# 42/42 - 0s - loss: 0.0422 - accuracy: 0.6133 - val_loss: 0.0450 - val_accuracy: 0.7235
# Epoch 29/300
# 42/42 - 0s - loss: 0.0426 - accuracy: 0.6093 - val_loss: 0.0457 - val_accuracy: 0.7299
# Epoch 30/300
# 42/42 - 0s - loss: 0.0429 - accuracy: 0.6097 - val_loss: 0.0462 - val_accuracy: 0.7122
# Epoch 31/300
# 42/42 - 0s - loss: 0.0427 - accuracy: 0.6197 - val_loss: 0.0456 - val_accuracy: 0.7203
# Epoch 32/300
# 42/42 - 0s - loss: 0.0415 - accuracy: 0.6207 - val_loss: 0.0454 - val_accuracy: 0.7347
# Epoch 33/300
# 42/42 - 0s - loss: 0.0409 - accuracy: 0.6213 - val_loss: 0.0448 - val_accuracy: 0.7251
# Epoch 34/300
# 42/42 - 0s - loss: 0.0409 - accuracy: 0.6193 - val_loss: 0.0449 - val_accuracy: 0.7219
# Epoch 35/300
# 42/42 - 0s - loss: 0.0407 - accuracy: 0.6260 - val_loss: 0.0439 - val_accuracy: 0.7299
# Epoch 36/300
# 42/42 - 0s - loss: 0.0401 - accuracy: 0.6293 - val_loss: 0.0436 - val_accuracy: 0.7299
# Epoch 37/300
# 42/42 - 0s - loss: 0.0399 - accuracy: 0.6347 - val_loss: 0.0436 - val_accuracy: 0.7412
# Epoch 38/300
# 42/42 - 0s - loss: 0.0399 - accuracy: 0.6330 - val_loss: 0.0433 - val_accuracy: 0.7283
# Epoch 39/300
# 42/42 - 0s - loss: 0.0398 - accuracy: 0.6360 - val_loss: 0.0440 - val_accuracy: 0.7363
# Epoch 40/300
# 42/42 - 0s - loss: 0.0400 - accuracy: 0.6353 - val_loss: 0.0438 - val_accuracy: 0.7283
# Epoch 41/300
# 42/42 - 0s - loss: 0.0398 - accuracy: 0.6313 - val_loss: 0.0431 - val_accuracy: 0.7251
# Epoch 42/300
# 42/42 - 0s - loss: 0.0395 - accuracy: 0.6313 - val_loss: 0.0430 - val_accuracy: 0.7299
# Epoch 43/300
# 42/42 - 0s - loss: 0.0397 - accuracy: 0.6337 - val_loss: 0.0427 - val_accuracy: 0.7283
# Epoch 44/300
# 42/42 - 0s - loss: 0.0395 - accuracy: 0.6317 - val_loss: 0.0433 - val_accuracy: 0.7235
# Epoch 45/300
# 42/42 - 0s - loss: 0.0397 - accuracy: 0.6343 - val_loss: 0.0434 - val_accuracy: 0.7315
# Epoch 46/300
# 42/42 - 0s - loss: 0.0395 - accuracy: 0.6403 - val_loss: 0.0425 - val_accuracy: 0.7347
# Epoch 47/300
# 42/42 - 0s - loss: 0.0391 - accuracy: 0.6403 - val_loss: 0.0424 - val_accuracy: 0.7460
# Epoch 48/300
# 42/42 - 0s - loss: 0.0391 - accuracy: 0.6390 - val_loss: 0.0435 - val_accuracy: 0.7315
# Epoch 49/300
# 42/42 - 0s - loss: 0.0402 - accuracy: 0.6350 - val_loss: 0.0436 - val_accuracy: 0.7540
# Epoch 50/300
# 42/42 - 0s - loss: 0.0395 - accuracy: 0.6303 - val_loss: 0.0429 - val_accuracy: 0.7492
# Epoch 51/300
# 42/42 - 0s - loss: 0.0400 - accuracy: 0.6367 - val_loss: 0.0427 - val_accuracy: 0.7460
# Epoch 52/300
# 42/42 - 0s - loss: 0.0393 - accuracy: 0.6370 - val_loss: 0.0431 - val_accuracy: 0.7444
# Epoch 53/300
# 42/42 - 0s - loss: 0.0394 - accuracy: 0.6383 - val_loss: 0.0430 - val_accuracy: 0.7492
# Epoch 54/300
# 42/42 - 0s - loss: 0.0396 - accuracy: 0.6350 - val_loss: 0.0428 - val_accuracy: 0.7460
# Epoch 55/300
# 42/42 - 0s - loss: 0.0398 - accuracy: 0.6303 - val_loss: 0.0431 - val_accuracy: 0.7444
# Epoch 56/300
# 42/42 - 0s - loss: 0.0398 - accuracy: 0.6390 - val_loss: 0.0436 - val_accuracy: 0.7412
# Epoch 57/300
# 42/42 - 0s - loss: 0.0393 - accuracy: 0.6330 - val_loss: 0.0425 - val_accuracy: 0.7379
# Epoch 58/300
# 42/42 - 0s - loss: 0.0386 - accuracy: 0.6430 - val_loss: 0.0425 - val_accuracy: 0.7395
# Epoch 59/300
# 42/42 - 0s - loss: 0.0386 - accuracy: 0.6383 - val_loss: 0.0426 - val_accuracy: 0.7379
# Epoch 60/300
# 42/42 - 0s - loss: 0.0385 - accuracy: 0.6367 - val_loss: 0.0430 - val_accuracy: 0.7379
# Epoch 61/300
# 42/42 - 0s - loss: 0.0391 - accuracy: 0.6300 - val_loss: 0.0432 - val_accuracy: 0.7331
# Epoch 62/300
# 42/42 - 0s - loss: 0.0388 - accuracy: 0.6310 - val_loss: 0.0436 - val_accuracy: 0.7395
# Epoch 63/300
# 42/42 - 0s - loss: 0.0391 - accuracy: 0.6287 - val_loss: 0.0432 - val_accuracy: 0.7331
# Epoch 64/300
# 42/42 - 0s - loss: 0.0385 - accuracy: 0.6407 - val_loss: 0.0422 - val_accuracy: 0.7412
# Epoch 65/300
# 42/42 - 0s - loss: 0.0376 - accuracy: 0.6437 - val_loss: 0.0419 - val_accuracy: 0.7428
# Epoch 66/300
# 42/42 - 0s - loss: 0.0373 - accuracy: 0.6407 - val_loss: 0.0419 - val_accuracy: 0.7428
# Epoch 67/300
# 42/42 - 0s - loss: 0.0372 - accuracy: 0.6410 - val_loss: 0.0420 - val_accuracy: 0.7444
# Epoch 68/300
# 42/42 - 0s - loss: 0.0372 - accuracy: 0.6413 - val_loss: 0.0421 - val_accuracy: 0.7476
# Epoch 69/300
# 42/42 - 0s - loss: 0.0376 - accuracy: 0.6440 - val_loss: 0.0422 - val_accuracy: 0.7492
# Epoch 70/300
# 42/42 - 0s - loss: 0.0376 - accuracy: 0.6497 - val_loss: 0.0428 - val_accuracy: 0.7524
# Epoch 71/300
# 42/42 - 0s - loss: 0.0379 - accuracy: 0.6490 - val_loss: 0.0424 - val_accuracy: 0.7524
# Epoch 72/300
# 42/42 - 0s - loss: 0.0378 - accuracy: 0.6453 - val_loss: 0.0424 - val_accuracy: 0.7492
# Epoch 73/300
# 42/42 - 0s - loss: 0.0378 - accuracy: 0.6367 - val_loss: 0.0422 - val_accuracy: 0.7379
# Epoch 74/300
# 42/42 - 0s - loss: 0.0376 - accuracy: 0.6367 - val_loss: 0.0422 - val_accuracy: 0.7379
# Epoch 75/300
# 42/42 - 0s - loss: 0.0371 - accuracy: 0.6473 - val_loss: 0.0421 - val_accuracy: 0.7476
# Epoch 76/300
# 42/42 - 0s - loss: 0.0368 - accuracy: 0.6480 - val_loss: 0.0418 - val_accuracy: 0.7492
# Epoch 77/300
# 42/42 - 0s - loss: 0.0366 - accuracy: 0.6507 - val_loss: 0.0418 - val_accuracy: 0.7444
# Epoch 78/300
# 42/42 - 0s - loss: 0.0362 - accuracy: 0.6473 - val_loss: 0.0416 - val_accuracy: 0.7492
# Epoch 79/300
# 42/42 - 0s - loss: 0.0363 - accuracy: 0.6497 - val_loss: 0.0415 - val_accuracy: 0.7444
# Epoch 80/300
# 42/42 - 0s - loss: 0.0362 - accuracy: 0.6490 - val_loss: 0.0414 - val_accuracy: 0.7476
# Epoch 81/300
# 42/42 - 0s - loss: 0.0362 - accuracy: 0.6483 - val_loss: 0.0416 - val_accuracy: 0.7508
# Epoch 82/300
# 42/42 - 0s - loss: 0.0361 - accuracy: 0.6503 - val_loss: 0.0418 - val_accuracy: 0.7524
# Epoch 83/300
# 42/42 - 0s - loss: 0.0362 - accuracy: 0.6523 - val_loss: 0.0415 - val_accuracy: 0.7428
# Epoch 84/300
# 42/42 - 0s - loss: 0.0361 - accuracy: 0.6523 - val_loss: 0.0417 - val_accuracy: 0.7524
# Epoch 85/300
# 42/42 - 0s - loss: 0.0362 - accuracy: 0.6530 - val_loss: 0.0419 - val_accuracy: 0.7428
# Epoch 86/300
# 42/42 - 0s - loss: 0.0363 - accuracy: 0.6553 - val_loss: 0.0415 - val_accuracy: 0.7460
# Epoch 87/300
# 42/42 - 0s - loss: 0.0362 - accuracy: 0.6517 - val_loss: 0.0416 - val_accuracy: 0.7476
# Epoch 88/300
# 42/42 - 0s - loss: 0.0358 - accuracy: 0.6527 - val_loss: 0.0415 - val_accuracy: 0.7428
# Epoch 89/300
# 42/42 - 0s - loss: 0.0359 - accuracy: 0.6507 - val_loss: 0.0415 - val_accuracy: 0.7428
# Epoch 90/300
# 42/42 - 0s - loss: 0.0360 - accuracy: 0.6497 - val_loss: 0.0416 - val_accuracy: 0.7444
# Epoch 91/300
# 42/42 - 0s - loss: 0.0361 - accuracy: 0.6513 - val_loss: 0.0416 - val_accuracy: 0.7412
# Epoch 92/300
# 42/42 - 0s - loss: 0.0364 - accuracy: 0.6477 - val_loss: 0.0415 - val_accuracy: 0.7460
# Epoch 93/300
# 42/42 - 0s - loss: 0.0363 - accuracy: 0.6480 - val_loss: 0.0414 - val_accuracy: 0.7395
# Epoch 94/300
# 42/42 - 0s - loss: 0.0360 - accuracy: 0.6510 - val_loss: 0.0413 - val_accuracy: 0.7347
# Epoch 95/300
# 42/42 - 0s - loss: 0.0357 - accuracy: 0.6507 - val_loss: 0.0412 - val_accuracy: 0.7347
# Epoch 96/300
# 42/42 - 0s - loss: 0.0356 - accuracy: 0.6520 - val_loss: 0.0412 - val_accuracy: 0.7395
# Epoch 97/300
# 42/42 - 0s - loss: 0.0355 - accuracy: 0.6583 - val_loss: 0.0412 - val_accuracy: 0.7379
# Epoch 98/300
# 42/42 - 0s - loss: 0.0355 - accuracy: 0.6577 - val_loss: 0.0412 - val_accuracy: 0.7428
# Epoch 99/300
# 42/42 - 0s - loss: 0.0356 - accuracy: 0.6553 - val_loss: 0.0411 - val_accuracy: 0.7363
# Epoch 100/300
# 42/42 - 0s - loss: 0.0355 - accuracy: 0.6550 - val_loss: 0.0414 - val_accuracy: 0.7251
# Epoch 101/300
# 42/42 - 0s - loss: 0.0361 - accuracy: 0.6477 - val_loss: 0.0420 - val_accuracy: 0.7251
# Epoch 102/300
# 42/42 - 0s - loss: 0.0369 - accuracy: 0.6403 - val_loss: 0.0451 - val_accuracy: 0.7122
# Epoch 103/300
# 42/42 - 0s - loss: 0.0378 - accuracy: 0.6300 - val_loss: 0.0453 - val_accuracy: 0.7251
# Epoch 104/300
# 42/42 - 0s - loss: 0.0368 - accuracy: 0.6517 - val_loss: 0.0439 - val_accuracy: 0.7235
# Epoch 105/300
# 42/42 - 0s - loss: 0.0358 - accuracy: 0.6607 - val_loss: 0.0438 - val_accuracy: 0.7219
# Epoch 106/300
# 42/42 - 0s - loss: 0.0357 - accuracy: 0.6533 - val_loss: 0.0434 - val_accuracy: 0.7203
# Epoch 107/300
# 42/42 - 0s - loss: 0.0355 - accuracy: 0.6543 - val_loss: 0.0430 - val_accuracy: 0.7203
# Epoch 108/300
# 42/42 - 0s - loss: 0.0355 - accuracy: 0.6577 - val_loss: 0.0435 - val_accuracy: 0.7106
# Epoch 109/300
# 42/42 - 0s - loss: 0.0355 - accuracy: 0.6547 - val_loss: 0.0438 - val_accuracy: 0.7106
# Epoch 110/300
# 42/42 - 0s - loss: 0.0356 - accuracy: 0.6510 - val_loss: 0.0442 - val_accuracy: 0.7138
# Epoch 111/300
# 42/42 - 0s - loss: 0.0356 - accuracy: 0.6583 - val_loss: 0.0437 - val_accuracy: 0.7186
# Epoch 112/300
# 42/42 - 0s - loss: 0.0354 - accuracy: 0.6627 - val_loss: 0.0436 - val_accuracy: 0.7138
# Epoch 113/300
# 42/42 - 0s - loss: 0.0352 - accuracy: 0.6643 - val_loss: 0.0435 - val_accuracy: 0.7026
# Epoch 114/300
# 42/42 - 0s - loss: 0.0350 - accuracy: 0.6630 - val_loss: 0.0435 - val_accuracy: 0.7154
# Epoch 115/300
# 42/42 - 0s - loss: 0.0348 - accuracy: 0.6653 - val_loss: 0.0433 - val_accuracy: 0.7090
# Epoch 116/300
# 42/42 - 0s - loss: 0.0347 - accuracy: 0.6710 - val_loss: 0.0427 - val_accuracy: 0.7138
# Epoch 117/300
# 42/42 - 0s - loss: 0.0349 - accuracy: 0.6627 - val_loss: 0.0435 - val_accuracy: 0.7154
# Epoch 118/300
# 42/42 - 0s - loss: 0.0350 - accuracy: 0.6683 - val_loss: 0.0434 - val_accuracy: 0.7170
# Epoch 119/300
# 42/42 - 0s - loss: 0.0351 - accuracy: 0.6583 - val_loss: 0.0440 - val_accuracy: 0.7315
# Epoch 120/300
# 42/42 - 0s - loss: 0.0355 - accuracy: 0.6517 - val_loss: 0.0439 - val_accuracy: 0.7331
# Epoch 121/300
# 42/42 - 0s - loss: 0.0353 - accuracy: 0.6563 - val_loss: 0.0437 - val_accuracy: 0.7267
# Epoch 122/300
# 42/42 - 0s - loss: 0.0349 - accuracy: 0.6583 - val_loss: 0.0435 - val_accuracy: 0.7251
# Epoch 123/300
# 42/42 - 0s - loss: 0.0348 - accuracy: 0.6633 - val_loss: 0.0435 - val_accuracy: 0.7283
# Epoch 124/300
# 42/42 - 0s - loss: 0.0347 - accuracy: 0.6623 - val_loss: 0.0435 - val_accuracy: 0.7267
# Epoch 125/300
# 42/42 - 0s - loss: 0.0344 - accuracy: 0.6663 - val_loss: 0.0429 - val_accuracy: 0.7170
# Epoch 126/300
# 42/42 - 0s - loss: 0.0345 - accuracy: 0.6703 - val_loss: 0.0432 - val_accuracy: 0.7267
# Epoch 127/300
# 42/42 - 0s - loss: 0.0347 - accuracy: 0.6723 - val_loss: 0.0435 - val_accuracy: 0.7203
# Epoch 128/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6747 - val_loss: 0.0430 - val_accuracy: 0.7186
# Epoch 129/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6750 - val_loss: 0.0429 - val_accuracy: 0.7090
# Epoch 130/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6690 - val_loss: 0.0430 - val_accuracy: 0.7122
# Epoch 131/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6737 - val_loss: 0.0426 - val_accuracy: 0.7090
# Epoch 132/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6740 - val_loss: 0.0430 - val_accuracy: 0.6994
# Epoch 133/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6743 - val_loss: 0.0433 - val_accuracy: 0.6994
# Epoch 134/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6743 - val_loss: 0.0437 - val_accuracy: 0.6977
# Epoch 135/300
# 42/42 - 0s - loss: 0.0338 - accuracy: 0.6773 - val_loss: 0.0428 - val_accuracy: 0.7203
# Epoch 136/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6720 - val_loss: 0.0434 - val_accuracy: 0.7058
# Epoch 137/300
# 42/42 - 0s - loss: 0.0340 - accuracy: 0.6790 - val_loss: 0.0434 - val_accuracy: 0.7138
# Epoch 138/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6740 - val_loss: 0.0436 - val_accuracy: 0.7154
# Epoch 139/300
# 42/42 - 0s - loss: 0.0345 - accuracy: 0.6730 - val_loss: 0.0445 - val_accuracy: 0.7251
# Epoch 140/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6810 - val_loss: 0.0443 - val_accuracy: 0.7283
# Epoch 141/300
# 42/42 - 0s - loss: 0.0345 - accuracy: 0.6783 - val_loss: 0.0440 - val_accuracy: 0.7251
# Epoch 142/300
# 42/42 - 0s - loss: 0.0343 - accuracy: 0.6780 - val_loss: 0.0439 - val_accuracy: 0.7299
# Epoch 143/300
# 42/42 - 0s - loss: 0.0339 - accuracy: 0.6790 - val_loss: 0.0434 - val_accuracy: 0.7235
# Epoch 144/300
# 42/42 - 0s - loss: 0.0338 - accuracy: 0.6813 - val_loss: 0.0433 - val_accuracy: 0.7299
# Epoch 145/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6813 - val_loss: 0.0432 - val_accuracy: 0.7170
# Epoch 146/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6777 - val_loss: 0.0433 - val_accuracy: 0.7283
# Epoch 147/300
# 42/42 - 0s - loss: 0.0338 - accuracy: 0.6777 - val_loss: 0.0431 - val_accuracy: 0.7299
# Epoch 148/300
# 42/42 - 0s - loss: 0.0339 - accuracy: 0.6823 - val_loss: 0.0442 - val_accuracy: 0.7283
# Epoch 149/300
# 42/42 - 0s - loss: 0.0340 - accuracy: 0.6783 - val_loss: 0.0445 - val_accuracy: 0.7186
# Epoch 150/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.6817 - val_loss: 0.0447 - val_accuracy: 0.7122
# Epoch 151/300
# 42/42 - 0s - loss: 0.0338 - accuracy: 0.6793 - val_loss: 0.0438 - val_accuracy: 0.7186
# Epoch 152/300
# 42/42 - 0s - loss: 0.0338 - accuracy: 0.6753 - val_loss: 0.0436 - val_accuracy: 0.7203
# Epoch 153/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6743 - val_loss: 0.0455 - val_accuracy: 0.7203
# Epoch 154/300
# 42/42 - 0s - loss: 0.0339 - accuracy: 0.6723 - val_loss: 0.0450 - val_accuracy: 0.7122
# Epoch 155/300
# 42/42 - 0s - loss: 0.0340 - accuracy: 0.6697 - val_loss: 0.0462 - val_accuracy: 0.7203
# Epoch 156/300
# 42/42 - 0s - loss: 0.0340 - accuracy: 0.6730 - val_loss: 0.0464 - val_accuracy: 0.7219
# Epoch 157/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6730 - val_loss: 0.0467 - val_accuracy: 0.7219
# Epoch 158/300
# 42/42 - 0s - loss: 0.0339 - accuracy: 0.6697 - val_loss: 0.0469 - val_accuracy: 0.7251
# Epoch 159/300
# 42/42 - 0s - loss: 0.0338 - accuracy: 0.6707 - val_loss: 0.0465 - val_accuracy: 0.7235
# Epoch 160/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6687 - val_loss: 0.0464 - val_accuracy: 0.7219
# Epoch 161/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.6773 - val_loss: 0.0453 - val_accuracy: 0.7299
# Epoch 162/300
# 42/42 - 0s - loss: 0.0338 - accuracy: 0.6750 - val_loss: 0.0451 - val_accuracy: 0.7154
# Epoch 163/300
# 42/42 - 0s - loss: 0.0338 - accuracy: 0.6720 - val_loss: 0.0448 - val_accuracy: 0.7122
# Epoch 164/300
# 42/42 - 0s - loss: 0.0336 - accuracy: 0.6750 - val_loss: 0.0449 - val_accuracy: 0.7026
# Epoch 165/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.6757 - val_loss: 0.0451 - val_accuracy: 0.7026
# Epoch 166/300
# 42/42 - 0s - loss: 0.0336 - accuracy: 0.6797 - val_loss: 0.0454 - val_accuracy: 0.7090
# Epoch 167/300
# 42/42 - 0s - loss: 0.0340 - accuracy: 0.6720 - val_loss: 0.0457 - val_accuracy: 0.7203
# Epoch 168/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6670 - val_loss: 0.0460 - val_accuracy: 0.7299
# Epoch 169/300
# 42/42 - 0s - loss: 0.0347 - accuracy: 0.6623 - val_loss: 0.0465 - val_accuracy: 0.7267
# Epoch 170/300
# 42/42 - 0s - loss: 0.0349 - accuracy: 0.6537 - val_loss: 0.0456 - val_accuracy: 0.7219
# Epoch 171/300
# 42/42 - 0s - loss: 0.0344 - accuracy: 0.6623 - val_loss: 0.0452 - val_accuracy: 0.7170
# Epoch 172/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6640 - val_loss: 0.0436 - val_accuracy: 0.7267
# Epoch 173/300
# 42/42 - 0s - loss: 0.0345 - accuracy: 0.6650 - val_loss: 0.0436 - val_accuracy: 0.7170
# Epoch 174/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6663 - val_loss: 0.0447 - val_accuracy: 0.7186
# Epoch 175/300
# 42/42 - 0s - loss: 0.0334 - accuracy: 0.6747 - val_loss: 0.0449 - val_accuracy: 0.7170
# Epoch 176/300
# 42/42 - 0s - loss: 0.0333 - accuracy: 0.6720 - val_loss: 0.0449 - val_accuracy: 0.7122
# Epoch 177/300
# 42/42 - 0s - loss: 0.0334 - accuracy: 0.6767 - val_loss: 0.0444 - val_accuracy: 0.7138
# Epoch 178/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.6760 - val_loss: 0.0441 - val_accuracy: 0.7203
# Epoch 179/300
# 42/42 - 0s - loss: 0.0333 - accuracy: 0.6780 - val_loss: 0.0442 - val_accuracy: 0.7170
# Epoch 180/300
# 42/42 - 0s - loss: 0.0335 - accuracy: 0.6733 - val_loss: 0.0445 - val_accuracy: 0.7154
# Epoch 181/300
# 42/42 - 0s - loss: 0.0332 - accuracy: 0.6783 - val_loss: 0.0449 - val_accuracy: 0.7170
# Epoch 182/300
# 42/42 - 0s - loss: 0.0331 - accuracy: 0.6810 - val_loss: 0.0450 - val_accuracy: 0.7186
# Epoch 183/300
# 42/42 - 0s - loss: 0.0332 - accuracy: 0.6747 - val_loss: 0.0453 - val_accuracy: 0.7219
# Epoch 184/300
# 42/42 - 0s - loss: 0.0332 - accuracy: 0.6777 - val_loss: 0.0446 - val_accuracy: 0.7170
# Epoch 185/300
# 42/42 - 0s - loss: 0.0335 - accuracy: 0.6787 - val_loss: 0.0446 - val_accuracy: 0.7219
# Epoch 186/300
# 42/42 - 0s - loss: 0.0344 - accuracy: 0.6743 - val_loss: 0.0463 - val_accuracy: 0.7154
# Epoch 187/300
# 42/42 - 0s - loss: 0.0343 - accuracy: 0.6753 - val_loss: 0.0475 - val_accuracy: 0.7106
# Epoch 188/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.6807 - val_loss: 0.0474 - val_accuracy: 0.7106
# Epoch 189/300
# 42/42 - 0s - loss: 0.0333 - accuracy: 0.6887 - val_loss: 0.0468 - val_accuracy: 0.7138
# Epoch 190/300
# 42/42 - 0s - loss: 0.0334 - accuracy: 0.6887 - val_loss: 0.0457 - val_accuracy: 0.7170
# Epoch 191/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.6863 - val_loss: 0.0455 - val_accuracy: 0.7267
# Epoch 192/300
# 42/42 - 0s - loss: 0.0336 - accuracy: 0.6897 - val_loss: 0.0463 - val_accuracy: 0.7251
# Epoch 193/300
# 42/42 - 0s - loss: 0.0339 - accuracy: 0.6873 - val_loss: 0.0470 - val_accuracy: 0.7251
# Epoch 194/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.6767 - val_loss: 0.0460 - val_accuracy: 0.6977
# Epoch 195/300
# 42/42 - 0s - loss: 0.0344 - accuracy: 0.6680 - val_loss: 0.0475 - val_accuracy: 0.6672
# Epoch 196/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6703 - val_loss: 0.0474 - val_accuracy: 0.6768
# Epoch 197/300
# 42/42 - 0s - loss: 0.0345 - accuracy: 0.6747 - val_loss: 0.0480 - val_accuracy: 0.7219
# Epoch 198/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6890 - val_loss: 0.0473 - val_accuracy: 0.7203
# Epoch 199/300
# 42/42 - 0s - loss: 0.0343 - accuracy: 0.6903 - val_loss: 0.0470 - val_accuracy: 0.7170
# Epoch 200/300
# 42/42 - 0s - loss: 0.0350 - accuracy: 0.6873 - val_loss: 0.0472 - val_accuracy: 0.7186
# Epoch 201/300
# 42/42 - 0s - loss: 0.0357 - accuracy: 0.6837 - val_loss: 0.0452 - val_accuracy: 0.7315
# Epoch 202/300
# 42/42 - 0s - loss: 0.0362 - accuracy: 0.6870 - val_loss: 0.0444 - val_accuracy: 0.7170
# Epoch 203/300
# 42/42 - 0s - loss: 0.0371 - accuracy: 0.6780 - val_loss: 0.0448 - val_accuracy: 0.6929
# Epoch 204/300
# 42/42 - 0s - loss: 0.0370 - accuracy: 0.6703 - val_loss: 0.0444 - val_accuracy: 0.6945
# Epoch 205/300
# 42/42 - 0s - loss: 0.0357 - accuracy: 0.6787 - val_loss: 0.0437 - val_accuracy: 0.7106
# Epoch 206/300
# 42/42 - 0s - loss: 0.0348 - accuracy: 0.6827 - val_loss: 0.0441 - val_accuracy: 0.7026
# Epoch 207/300
# 42/42 - 0s - loss: 0.0345 - accuracy: 0.6797 - val_loss: 0.0442 - val_accuracy: 0.7074
# Epoch 208/300
# 42/42 - 0s - loss: 0.0346 - accuracy: 0.6753 - val_loss: 0.0449 - val_accuracy: 0.6785
# Epoch 209/300
# 42/42 - 0s - loss: 0.0347 - accuracy: 0.6803 - val_loss: 0.0444 - val_accuracy: 0.6929
# Epoch 210/300
# 42/42 - 0s - loss: 0.0347 - accuracy: 0.6860 - val_loss: 0.0443 - val_accuracy: 0.7010
# Epoch 211/300
# 42/42 - 0s - loss: 0.0349 - accuracy: 0.6890 - val_loss: 0.0438 - val_accuracy: 0.7042
# Epoch 212/300
# 42/42 - 0s - loss: 0.0342 - accuracy: 0.6850 - val_loss: 0.0436 - val_accuracy: 0.7106
# Epoch 213/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6890 - val_loss: 0.0439 - val_accuracy: 0.7090
# Epoch 214/300
# 42/42 - 0s - loss: 0.0336 - accuracy: 0.6897 - val_loss: 0.0439 - val_accuracy: 0.7074
# Epoch 215/300
# 42/42 - 0s - loss: 0.0333 - accuracy: 0.6913 - val_loss: 0.0438 - val_accuracy: 0.7090
# Epoch 216/300
# 42/42 - 0s - loss: 0.0334 - accuracy: 0.6957 - val_loss: 0.0437 - val_accuracy: 0.7122
# Epoch 217/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.6947 - val_loss: 0.0439 - val_accuracy: 0.7138
# Epoch 218/300
# 42/42 - 0s - loss: 0.0339 - accuracy: 0.6953 - val_loss: 0.0436 - val_accuracy: 0.7203
# Epoch 219/300
# 42/42 - 0s - loss: 0.0340 - accuracy: 0.6947 - val_loss: 0.0435 - val_accuracy: 0.7315
# Epoch 220/300
# 42/42 - 0s - loss: 0.0341 - accuracy: 0.6940 - val_loss: 0.0434 - val_accuracy: 0.7138
# Epoch 221/300
# 42/42 - 0s - loss: 0.0337 - accuracy: 0.7000 - val_loss: 0.0434 - val_accuracy: 0.7267
# Epoch 222/300
# 42/42 - 0s - loss: 0.0332 - accuracy: 0.7003 - val_loss: 0.0432 - val_accuracy: 0.7251
# Epoch 223/300
# 42/42 - 0s - loss: 0.0330 - accuracy: 0.6980 - val_loss: 0.0433 - val_accuracy: 0.7267
# Epoch 224/300
# 42/42 - 0s - loss: 0.0327 - accuracy: 0.7013 - val_loss: 0.0435 - val_accuracy: 0.7283
# Epoch 225/300
# 42/42 - 0s - loss: 0.0329 - accuracy: 0.6937 - val_loss: 0.0438 - val_accuracy: 0.7106
# Epoch 226/300
# 42/42 - 0s - loss: 0.0324 - accuracy: 0.6917 - val_loss: 0.0438 - val_accuracy: 0.7219
# Epoch 227/300
# 42/42 - 0s - loss: 0.0323 - accuracy: 0.7000 - val_loss: 0.0438 - val_accuracy: 0.7283
# Epoch 228/300
# 42/42 - 0s - loss: 0.0322 - accuracy: 0.7007 - val_loss: 0.0441 - val_accuracy: 0.7235
# Epoch 229/300
# 42/42 - 0s - loss: 0.0324 - accuracy: 0.7000 - val_loss: 0.0442 - val_accuracy: 0.7138
# Epoch 230/300
# 42/42 - 0s - loss: 0.0324 - accuracy: 0.7013 - val_loss: 0.0443 - val_accuracy: 0.7106
# Epoch 231/300
# 42/42 - 0s - loss: 0.0323 - accuracy: 0.6967 - val_loss: 0.0440 - val_accuracy: 0.7170
# Epoch 232/300
# 42/42 - 0s - loss: 0.0322 - accuracy: 0.7013 - val_loss: 0.0444 - val_accuracy: 0.7122
# Epoch 233/300
# 42/42 - 0s - loss: 0.0322 - accuracy: 0.7053 - val_loss: 0.0445 - val_accuracy: 0.7186
# Epoch 234/300
# 42/42 - 0s - loss: 0.0320 - accuracy: 0.7063 - val_loss: 0.0442 - val_accuracy: 0.7219
# Epoch 235/300
# 42/42 - 0s - loss: 0.0321 - accuracy: 0.7060 - val_loss: 0.0444 - val_accuracy: 0.7299
# Epoch 236/300
# 42/42 - 0s - loss: 0.0319 - accuracy: 0.7100 - val_loss: 0.0444 - val_accuracy: 0.7154
# Epoch 237/300
# 42/42 - 0s - loss: 0.0318 - accuracy: 0.7073 - val_loss: 0.0444 - val_accuracy: 0.7074
# Epoch 238/300
# 42/42 - 0s - loss: 0.0319 - accuracy: 0.7060 - val_loss: 0.0449 - val_accuracy: 0.7010
# Epoch 239/300
# 42/42 - 0s - loss: 0.0317 - accuracy: 0.7037 - val_loss: 0.0441 - val_accuracy: 0.7170
# Epoch 240/300
# 42/42 - 0s - loss: 0.0319 - accuracy: 0.7103 - val_loss: 0.0447 - val_accuracy: 0.7010
# Epoch 241/300
# 42/42 - 0s - loss: 0.0320 - accuracy: 0.7037 - val_loss: 0.0441 - val_accuracy: 0.7219
# Epoch 242/300
# 42/42 - 0s - loss: 0.0320 - accuracy: 0.7167 - val_loss: 0.0446 - val_accuracy: 0.7154
# Epoch 243/300
# 42/42 - 0s - loss: 0.0316 - accuracy: 0.7067 - val_loss: 0.0444 - val_accuracy: 0.7203
# Epoch 244/300
# 42/42 - 0s - loss: 0.0315 - accuracy: 0.7147 - val_loss: 0.0449 - val_accuracy: 0.7106
# Epoch 245/300
# 42/42 - 0s - loss: 0.0313 - accuracy: 0.7100 - val_loss: 0.0443 - val_accuracy: 0.7170
# Epoch 246/300
# 42/42 - 0s - loss: 0.0315 - accuracy: 0.7133 - val_loss: 0.0445 - val_accuracy: 0.7074
# Epoch 247/300
# 42/42 - 0s - loss: 0.0313 - accuracy: 0.7093 - val_loss: 0.0442 - val_accuracy: 0.7074
# Epoch 248/300
# 42/42 - 0s - loss: 0.0314 - accuracy: 0.7143 - val_loss: 0.0442 - val_accuracy: 0.7074
# Epoch 249/300
# 42/42 - 0s - loss: 0.0315 - accuracy: 0.7053 - val_loss: 0.0442 - val_accuracy: 0.7074
# Epoch 250/300
# 42/42 - 0s - loss: 0.0315 - accuracy: 0.7053 - val_loss: 0.0447 - val_accuracy: 0.6994
# Epoch 251/300
# 42/42 - 0s - loss: 0.0318 - accuracy: 0.6993 - val_loss: 0.0455 - val_accuracy: 0.6576
# Epoch 252/300
# 42/42 - 0s - loss: 0.0316 - accuracy: 0.7057 - val_loss: 0.0458 - val_accuracy: 0.6720
# Epoch 253/300
# 42/42 - 0s - loss: 0.0316 - accuracy: 0.7020 - val_loss: 0.0465 - val_accuracy: 0.6576
# Epoch 254/300
# 42/42 - 0s - loss: 0.0312 - accuracy: 0.7080 - val_loss: 0.0454 - val_accuracy: 0.6849
# Epoch 255/300
# 42/42 - 0s - loss: 0.0313 - accuracy: 0.7060 - val_loss: 0.0446 - val_accuracy: 0.7090
# Epoch 256/300
# 42/42 - 0s - loss: 0.0317 - accuracy: 0.6973 - val_loss: 0.0451 - val_accuracy: 0.6897
# Epoch 257/300
# 42/42 - 0s - loss: 0.0314 - accuracy: 0.7003 - val_loss: 0.0448 - val_accuracy: 0.6913
# Epoch 258/300
# 42/42 - 0s - loss: 0.0312 - accuracy: 0.7027 - val_loss: 0.0450 - val_accuracy: 0.6817
# Epoch 259/300
# 42/42 - 0s - loss: 0.0312 - accuracy: 0.7057 - val_loss: 0.0456 - val_accuracy: 0.6752
# Epoch 260/300
# 42/42 - 0s - loss: 0.0317 - accuracy: 0.7003 - val_loss: 0.0469 - val_accuracy: 0.6576
# Epoch 261/300
# 42/42 - 0s - loss: 0.0311 - accuracy: 0.7040 - val_loss: 0.0456 - val_accuracy: 0.6913
# Epoch 262/300
# 42/42 - 0s - loss: 0.0315 - accuracy: 0.7100 - val_loss: 0.0456 - val_accuracy: 0.6833
# Epoch 263/300
# 42/42 - 0s - loss: 0.0311 - accuracy: 0.7027 - val_loss: 0.0453 - val_accuracy: 0.6961
# Epoch 264/300
# 42/42 - 0s - loss: 0.0314 - accuracy: 0.6930 - val_loss: 0.0451 - val_accuracy: 0.6945
# Epoch 265/300
# 42/42 - 0s - loss: 0.0310 - accuracy: 0.7000 - val_loss: 0.0450 - val_accuracy: 0.7042
# Epoch 266/300
# 42/42 - 0s - loss: 0.0311 - accuracy: 0.6997 - val_loss: 0.0450 - val_accuracy: 0.7042
# Epoch 267/300
# 42/42 - 0s - loss: 0.0313 - accuracy: 0.7033 - val_loss: 0.0452 - val_accuracy: 0.6961
# Epoch 268/300
# 42/42 - 0s - loss: 0.0309 - accuracy: 0.6950 - val_loss: 0.0449 - val_accuracy: 0.7106
# Epoch 269/300
# 42/42 - 0s - loss: 0.0309 - accuracy: 0.7000 - val_loss: 0.0446 - val_accuracy: 0.7058
# Epoch 270/300
# 42/42 - 0s - loss: 0.0307 - accuracy: 0.7080 - val_loss: 0.0446 - val_accuracy: 0.7138
# Epoch 271/300
# 42/42 - 0s - loss: 0.0311 - accuracy: 0.6997 - val_loss: 0.0440 - val_accuracy: 0.7170
# Epoch 272/300
# 42/42 - 0s - loss: 0.0315 - accuracy: 0.6987 - val_loss: 0.0440 - val_accuracy: 0.7299
# Epoch 273/300
# 42/42 - 0s - loss: 0.0316 - accuracy: 0.7030 - val_loss: 0.0440 - val_accuracy: 0.7219
# Epoch 274/300
# 42/42 - 0s - loss: 0.0311 - accuracy: 0.7060 - val_loss: 0.0440 - val_accuracy: 0.7251
# Epoch 275/300
# 42/42 - 0s - loss: 0.0310 - accuracy: 0.7043 - val_loss: 0.0441 - val_accuracy: 0.7235
# Epoch 276/300
# 42/42 - 0s - loss: 0.0307 - accuracy: 0.7143 - val_loss: 0.0443 - val_accuracy: 0.7235
# Epoch 277/300
# 42/42 - 0s - loss: 0.0305 - accuracy: 0.7107 - val_loss: 0.0442 - val_accuracy: 0.7203
# Epoch 278/300
# 42/42 - 0s - loss: 0.0305 - accuracy: 0.7190 - val_loss: 0.0444 - val_accuracy: 0.7170
# Epoch 279/300
# 42/42 - 0s - loss: 0.0305 - accuracy: 0.7187 - val_loss: 0.0443 - val_accuracy: 0.7267
# Epoch 280/300
# 42/42 - 0s - loss: 0.0301 - accuracy: 0.7187 - val_loss: 0.0441 - val_accuracy: 0.7235
# Epoch 281/300
# 42/42 - 0s - loss: 0.0302 - accuracy: 0.7280 - val_loss: 0.0445 - val_accuracy: 0.7283
# Epoch 282/300
# 42/42 - 0s - loss: 0.0302 - accuracy: 0.7227 - val_loss: 0.0445 - val_accuracy: 0.7299
# Epoch 283/300
# 42/42 - 0s - loss: 0.0300 - accuracy: 0.7207 - val_loss: 0.0446 - val_accuracy: 0.7219
# Epoch 284/300
# 42/42 - 0s - loss: 0.0300 - accuracy: 0.7263 - val_loss: 0.0445 - val_accuracy: 0.7235
# Epoch 285/300
# 42/42 - 0s - loss: 0.0298 - accuracy: 0.7277 - val_loss: 0.0449 - val_accuracy: 0.7186
# Epoch 286/300
# 42/42 - 0s - loss: 0.0298 - accuracy: 0.7297 - val_loss: 0.0443 - val_accuracy: 0.7251
# Epoch 287/300
# 42/42 - 0s - loss: 0.0298 - accuracy: 0.7230 - val_loss: 0.0447 - val_accuracy: 0.7283
# Epoch 288/300
# 42/42 - 0s - loss: 0.0298 - accuracy: 0.7273 - val_loss: 0.0447 - val_accuracy: 0.7267
# Epoch 289/300
# 42/42 - 0s - loss: 0.0301 - accuracy: 0.7280 - val_loss: 0.0445 - val_accuracy: 0.7251
# Epoch 290/300
# 42/42 - 0s - loss: 0.0304 - accuracy: 0.7323 - val_loss: 0.0451 - val_accuracy: 0.7283
# Epoch 291/300
# 42/42 - 0s - loss: 0.0307 - accuracy: 0.7237 - val_loss: 0.0447 - val_accuracy: 0.7219
# Epoch 292/300
# 42/42 - 0s - loss: 0.0298 - accuracy: 0.7247 - val_loss: 0.0446 - val_accuracy: 0.7219
# Epoch 293/300
# 42/42 - 0s - loss: 0.0300 - accuracy: 0.7277 - val_loss: 0.0444 - val_accuracy: 0.7090
# Epoch 294/300
# 42/42 - 0s - loss: 0.0298 - accuracy: 0.7207 - val_loss: 0.0445 - val_accuracy: 0.7090
# Epoch 295/300
# 42/42 - 0s - loss: 0.0299 - accuracy: 0.7267 - val_loss: 0.0444 - val_accuracy: 0.7106
# Epoch 296/300
# 42/42 - 0s - loss: 0.0299 - accuracy: 0.7223 - val_loss: 0.0448 - val_accuracy: 0.7122
# Epoch 297/300
# 42/42 - 0s - loss: 0.0297 - accuracy: 0.7270 - val_loss: 0.0445 - val_accuracy: 0.7235
# Epoch 298/300
# 42/42 - 0s - loss: 0.0298 - accuracy: 0.7267 - val_loss: 0.0448 - val_accuracy: 0.7106
# Epoch 299/300
# 42/42 - 0s - loss: 0.0306 - accuracy: 0.7183 - val_loss: 0.0453 - val_accuracy: 0.6994
# Epoch 300/300
# 42/42 - 0s - loss: 0.0307 - accuracy: 0.7223 - val_loss: 0.0450 - val_accuracy: 0.7074

# %%
import datetime
plt.rcParams.update({'font.size': 14})

# %%
f = pyplot.figure()
pyplot.plot(history.history['val_accuracy'], label='val_accuracy')
pyplot.plot(history.history['accuracy'], label='accuracy')
pyplot.legend()
pyplot.xlabel('Epochs')
pyplot.ylabel('accuracy')
pyplot.title('LSTM-2 Training and Testing accuracy')
pyplot.savefig('LSTM/lstm-2-acc.png')
pyplot.show()
now = datetime.datetime.now()

# %%
f1 = pyplot.figure()
pyplot.plot(history.history['loss'], label='train loss')
pyplot.plot(history.history['val_loss'], label='val loss')
pyplot.legend()
pyplot.xlabel('Epochs')
pyplot.ylabel('loss')
pyplot.title('LSTM-2 Train and Test Loss')
pyplot.savefig('LSTM/lstm-2-loss.png')
pyplot.show()
now = datetime.datetime.now()

# %%
end-start
# Out:
# 105.69658994674683

# %%
# make a prediction
yhat = model.predict(test_X)

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, test_X[:, 84:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,:]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), N))
inv_y = np.concatenate((test_y, test_X[:, 84:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,:]
print(inv_y.shape)
f3 = pyplot.figure(figsize=(20,10))
pyplot.subplot(6, 1, 1)
pyplot.plot(inv_y[:,0],label='Y0_Brooklyn')
pyplot.plot(inv_yhat[:,0],label='Yhat_Brooklyn')
pyplot.xlabel("Epochs")
pyplot.ylabel("Pickups")
pyplot.legend()

pyplot.subplot(6, 1, 2)
pyplot.plot(inv_y[:,1],label='y1_Manhattan')
pyplot.plot(inv_yhat[:,1],label='yhat1_Manhattan')
pyplot.xlabel("Epochs")
pyplot.ylabel("Pickups")
pyplot.legend()

pyplot.subplot(6, 1, 3)
pyplot.plot(inv_y[:,2],label='y2_Queens')
pyplot.plot(inv_yhat[:,2],label='yhat2_Queens')
pyplot.xlabel("Epochs")
pyplot.ylabel("Pickups")
pyplot.legend()

pyplot.subplot(6, 1, 4)
pyplot.plot(inv_y[:,3],label='y3_EWR')
pyplot.plot(inv_yhat[:,3],label='yhat3_EWR')
pyplot.xlabel("Epochs")
pyplot.ylabel("Pickups")
pyplot.legend()

pyplot.subplot(6, 1, 5)
pyplot.plot(inv_y[:,4],label='y4_Bronx')
pyplot.plot(inv_yhat[:,4],label='yhat4_Bronx')
pyplot.xlabel("Epochs")
pyplot.ylabel("Pickups")
pyplot.legend()

pyplot.subplot(6, 1, 6)
pyplot.plot(inv_y[:,5],label='y5_Staten Island')
pyplot.plot(inv_yhat[:,5],label='yhat5_Staten Island')
pyplot.xlabel("Epochs")
pyplot.ylabel("Pickups")
pyplot.legend()
f3.suptitle('Uber demand forecasting for LSTM-2')

pyplot.savefig('LSTM/LSTM-2_forecast.png')
pyplot.show()
now = datetime.datetime.now()
# Out:
# (622, 14)

# %%
# calculate RMSE
import math
from sklearn.metrics import mean_squared_error

rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 15.339

# %%
abs(end-start)
# Out:
# 105.69658994674683

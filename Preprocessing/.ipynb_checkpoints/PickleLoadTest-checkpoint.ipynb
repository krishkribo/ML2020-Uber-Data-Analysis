# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import nbimporter
import commons.utility.pickle_util as pickle
import DataEnrichment as de
import matplotlib.pyplot as plt
# Out:
# Importing Jupyter notebook from D:\Academics\MLRepoNew\ML2020-Uber-Data-Analysis\commons\utility\pickle_util.ipynb
# Importing Jupyter notebook from DataEnrichment.ipynb

# %% [markdown]
# ## Reading Data using pickle

# %%
pickle.load('../data/picklerCheckpoints/enrichedData/uber-enriched-data-may14.p', True)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/picklerCheckpoints/enrichedData/uber-enriched-data-may14.p
# Decompressing ../data/picklerCheckpoints/enrichedData/uber-enriched-data-may14.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                  Date/Time      Lat      Lon    Base       datetime  \
# 0         5/1/2014 0:02:00  40.7521 -73.9914  B02512  05-01-2014:00
# 1         5/1/2014 0:06:00  40.6965 -73.9715  B02512  05-01-2014:00
# 2         5/1/2014 0:15:00  40.7464 -73.9838  B02512  05-01-2014:00
# 3         5/1/2014 0:17:00  40.7463 -74.0011  B02512  05-01-2014:00
# 4         5/1/2014 0:17:00  40.7594 -73.9734  B02512  05-01-2014:00
# ...                    ...      ...      ...     ...            ...
# 652430  5/31/2014 23:45:00  40.7309 -74.0014  B02764  05-31-2014:23
# ...

# %% [markdown]
# ## Reading enriched data made easier
# ### Simply enter the valid month enumeration to fetch the data
# ### Valid months are:
# apr
# may
# jun
# jul
# aug
# sep
#
# #### Note: Files will be regenerated if it does not exist.

# %%
df = de.getUberDataforMonth('aug')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/picklerCheckpoints/enrichedData/uber-enriched-data-aug14.p
# Decompressing ../data/picklerCheckpoints/enrichedData/uber-enriched-data-aug14.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Dataset loaded

# %%
 df.plot(kind='scatter', x='Lon', y='Lat')
# Out:
# <AxesSubplot:xlabel='Lon', ylabel='Lat'>

# %%
df.sample(50000).plot(kind='scatter', x='Lon', y='Lat')
# Out:
# <AxesSubplot:xlabel='Lon', ylabel='Lat'>

# %%
df
# Out:
#                  Date/Time      Lat      Lon    Base       datetime  \
# 0         8/1/2014 0:03:00  40.7366 -73.9906  B02512  08-01-2014:00
# 1         8/1/2014 0:09:00  40.7260 -73.9918  B02512  08-01-2014:00
# 2         8/1/2014 0:12:00  40.7209 -74.0507  B02512  08-01-2014:00
# 3         8/1/2014 0:12:00  40.7387 -73.9856  B02512  08-01-2014:00
# 4         8/1/2014 0:12:00  40.7323 -74.0077  B02512  08-01-2014:00
# ...                    ...      ...      ...     ...            ...
# 829270  8/31/2014 23:55:00  40.7552 -73.9753  B02764  08-31-2014:23
# 829271  8/31/2014 23:55:00  40.7552 -73.9753  B02764  08-31-2014:23
# 829272  8/31/2014 23:55:00  40.7617 -73.9788  B02764  08-31-2014:23
# 829273  8/31/2014 23:59:00  40.7395 -73.9889  B02764  08-31-2014:23
# 829274  8/31/2014 23:59:00  40.7270 -73.9802  B02764  08-31-2014:23
#
#        weatherCondition  humidity  pressure  temperature  windDirection  \
# 0         broken clouds      57.0    1019.0       297.51            0.0
# ...

# %% [markdown]
# ### Reading Data with Spatial information

# %%
import Preprocessing.SpatialMapping as sm
# Out:
# Importing Jupyter notebook from D:\Academics\MLRepoNew\ML2020-Uber-Data-Analysis\Preprocessing\SpatialMapping.ipynb
# Importing Jupyter notebook from D:\Academics\MLRepoNew\ML2020-Uber-Data-Analysis\Preprocessing\DataEnrichment.ipynb

# %%
june = sm.run(['jun'])
# Out:
# Spatial join of all months found...Loading...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-14.p
# Decompressing ../data/picklerCheckpoints/spatialJoinData/uber-spatial-data-14.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
june
# Out:
#                   Date/Time      Lat      Lon    Base       datetime  \
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512  04-01-2014:00
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512  04-01-2014:00
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512  04-01-2014:00
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512  04-01-2014:00
# 2          4/1/2014 0:21:00  40.7316 -73.9873  B02512  04-01-2014:00
# ...                     ...      ...      ...     ...            ...
# 1028134  9/30/2014 22:58:00  40.7081 -74.0066  B02764  09-30-2014:22
# 1028134  9/30/2014 22:58:00  40.7081 -74.0066  B02764  09-30-2014:22
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764  09-30-2014:22
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764  09-30-2014:22
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764  09-30-2014:22
#
#          weatherCondition  humidity  pressure  temperature  windDirection  \
# ...

# %% [markdown]
# ### Discretizing and Reverting

# %%
import Preprocessing.Discretization as Dis
# Out:
# Importing Jupyter notebook from D:\Academics\MLRepoNew\ML2020-Uber-Data-Analysis\Preprocessing\Discretization.ipynb

# %%
encodeJune = Dis.encode(june, ['weatherCondition'])
# Out:
# Result Saved in ../data/encodedMappings/weatherCondition.p

# %%
encodeJune.head(3)
# Out:
#           Date/Time     Lat      Lon    Base       datetime  weatherCondition  \
# 0  4/1/2014 0:11:00  40.769 -73.9549  B02512  04-01-2014:00                15
# 0  4/1/2014 0:11:00  40.769 -73.9549  B02512  04-01-2014:00                15
# 0  4/1/2014 0:11:00  40.769 -73.9549  B02512  04-01-2014:00                15
#
#    humidity  pressure  temperature  windDirection  windSpeed  \
# 0      40.0    1016.0       282.96          330.0        5.0
# 0      40.0    1016.0       282.96          330.0        5.0
# 0      40.0    1016.0       282.96          330.0        5.0
#
#                      geometry  index_right             zone  LocationID  \
# 0  POINT (-73.95490 40.76900)         42.0     Central Park        43.0
# 0  POINT (-73.95490 40.76900)        139.0  Lenox Hill East       140.0
# 0  POINT (-73.95490 40.76900)        140.0  Lenox Hill West       141.0
#
#      borough  borough_categ
# 0  Manhattan            3.0
# 0  Manhattan            3.0
# ...

# %%
decodedJune = Dis.decode(june, ['weatherCondition'])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Loading file ../data/encodedMappings/weatherCondition.p
# Decompressing ../data/encodedMappings/weatherCondition.p.pbz2..............Done
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# {0: 'broken clouds', 1: 'drizzle', 2: 'dust', 3: 'few clouds', 4: 'fog', 5: 'haze', 6: 'heavy intensity drizzle', 7: 'heavy intensity rain', 8: 'light intensity drizzle', 9: 'light rain', 10: 'mist', 11: 'moderate rain', 12: 'overcast clouds', 13: 'proximity thunderstorm', 14: 'proximity thunderstorm with rain', 15: 'scattered clouds', 16: 'sky is clear', 17: 'smoke', 18: 'thunderstorm', 19: 'thunderstorm with heavy rain', 20: 'thunderstorm with light rain', 21: 'thunderstorm with rain', 22: 'very heavy rain'}

# %%
decodedJune
# Out:
#                   Date/Time      Lat      Lon    Base       datetime  \
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512  04-01-2014:00
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512  04-01-2014:00
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512  04-01-2014:00
# 0          4/1/2014 0:11:00  40.7690 -73.9549  B02512  04-01-2014:00
# 2          4/1/2014 0:21:00  40.7316 -73.9873  B02512  04-01-2014:00
# ...                     ...      ...      ...     ...            ...
# 1028134  9/30/2014 22:58:00  40.7081 -74.0066  B02764  09-30-2014:22
# 1028134  9/30/2014 22:58:00  40.7081 -74.0066  B02764  09-30-2014:22
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764  09-30-2014:22
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764  09-30-2014:22
# 1028135  9/30/2014 22:58:00  40.7140 -73.9496  B02764  09-30-2014:22
#
#          weatherCondition  humidity  pressure  temperature  windDirection  \
# ...
